# %% [markdown]
# # Day 2 class material: Pandas
#
# - Programming in Python for Business and Life Science Analytics (MGT001437, englisch)
# - School of Management & School of Life Sciences, <span style = "color: blue">Technical University of Munich</span>

# %% [markdown]
# __Pandas__ provides powerful tools to read, manipulate, and analyze data efficiently.

# %%
# pip install pandas
import pandas as pd

# %%
df.read_csv("data.csv")
df.to_excel("data.xlsx", index = False)
df.to_csv("data_new.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/91/gbg7fcg52bn_nx2ht6x1vgz00000gn/T/ipykernel_25524/1997131762.py in ?()
# ----> 1 df.read_csv("data.csv")
#       2 df.to_excel("data.xlsx", index = False)
#       3 df.to_csv("data_new.csv", index = False)
#
# /opt/miniconda3/envs/VE_Seminar/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
# The current folder.
path = "./"

# %% [markdown]
# Initialize a dataframe: From Lists to DataFrame

# %%
# A simple list
data_list = [10, 20, 30, 40, 50]

# Convert list to DataFrame
df = pd.DataFrame(data_list, columns=['Numbers'])

# %%
df
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50

# %%
df['alphabet']  =  ['a','b','c','d','e']
df
# Out:
#    Numbers alphabet
# 0       10        a
# 1       20        b
# 2       30        c
# 3       40        d
# 4       50        e

# %%
# nested list
data = [['a', 1],
        ['b', 2]]

# Convert list to DataFrame
df = pd.DataFrame(data, columns = ['model', 'price'])

df
# Out:
#   model  price
# 0     a      1
# 1     b      2

# %%
# A list of dictionaries
data_list = [
    {'ID': 1, 'Name': 'Alice', 'Age': 24},
    {'ID': 2, 'Name': 'Bob', 'Age': 19},
    {'ID': 3, 'Name': 'Charlie', 'Age': 23}
]

# Convert list to DataFrame
df = pd.DataFrame(data_list)

df
# Out:
#    ID     Name  Age
# 0   1    Alice   24
# 1   2      Bob   19
# 2   3  Charlie   23

# %% [markdown]
# From Dictionaries to DataFrame
# - When you have a dictionary where each key corresponds to a list of values, pandas will treat the keys as column names and the lists as the data for those columns.

# %%
# Dictionary of lists
data = {
    'model': ['a', 'b'], 
    'price' : [1,2]
    }

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# - the scalar value __True__ for 'Employed' will be repeated for all rows in the DataFrame, showing how pandas can broadcast a single value across multiple rows.

# %%
# Dictionary with mixed types
data_dict = {
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Employed': True  # Scalar value, will be broadcasted
}

# Convert dictionary to DataFrame
df = pd.DataFrame(data_dict)

df
# Out:
#    ID     Name  Employed
# 0   1    Alice      True
# 1   2      Bob      True
# 2   3  Charlie      True

# %%
# Dictionary of dictionaries
data_dict = {
   # index 
    '100': {'Name': 'Alice', 'Age': 24},
    '101': {'Name': 'Bob', 'Age': 19},
    '102': {'Name': 'Charlie', 'Age': 23}
}

# Convert dictionary to DataFrame
df1 = pd.DataFrame.from_dict(data_dict, orient='index')

df1
# Out:
#         Name  Age
# 100    Alice   24
# 101      Bob   19
# 102  Charlie   23

# %% [markdown]
# - add a new column 'ID'
# - pd.concat
# - .T
# - read excel @ ExcelFile

# %%
xls = pd.ExcelFile('Sectors_agg.xlsx')

pd.read_excel #only the first sheet

# to read all sheets to a map
sheet_to_df_map = {}
for sheet_name in xls.sheet_names: 
    sheet_to_df_map[sheet_name] = xls.parse(sheet_name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/miniconda3/envs/VE_Seminar/lib/python3.11/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /opt/miniconda3/envs/VE_Seminar/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 xls = pd.ExcelFile('Sectors_agg.xlsx')
#       3 pd.read_excel #only the first sheet
#       5 # to read all sheets to a map
#
# File /opt/miniconda3/envs/VE_Seminar/lib/python3.11/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File /opt/miniconda3/envs/VE_Seminar/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)    539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)    550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File /opt/miniconda3/envs/VE_Seminar/lib/python3.11/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %% [markdown]
# -  __DataFrame__: a DataFrame is a tabular data structure with rows and columns, similar to a spreadsheet.
# Read CSV: https://www.geeksforgeeks.org/python-read-csv-using-pandas-read_csv/
#
# ### Sample Data Structure:
# - __Date__: The date on which the data was recorded, formatted as YYYY-MM-DD.
# - __Store__: An identifier for the store, which appears to be a numerical ID.
# - __Temperature__: The temperature on the recorded date, in degrees Fahrenheit.
# - __Fuel_Price__: The cost of fuel per gallon on the recorded date, in USD.
# - __MarkDown1 to MarkDown5__: These columns represent promotional markdowns at the store. Not all markdowns are applied on all days, as indicated by empty fields.
# - __CPI__: The Consumer Price Index on the recorded date, a measure that estimates the average price of consumer goods and services purchased by households.
# - __Unemployment__: The unemployment rate as a percentage on the recorded date, indicating the economic condition around the area of the store.
# - __IsHoliday__: A boolean value (TRUE or FALSE) indicating whether the recorded date was a holiday.

# %%
# Step 1: Read csv file
filename = "store1features.csv"
df = pd.read_csv(filename)
# index_col = ['Date', 'Store']
# usecols=['Date','Store', 'Temperature','Fuel_Price']
df.head() # top 5 rows with the latest 5 rows
# Out:
#          Date  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0  2010-02-05      1        42.31       2.572        NaN        NaN
# 1  2010-02-12      1        38.51       2.548        NaN        NaN
# 2  2010-02-19      1        39.93       2.514        NaN        NaN
# 3  2010-02-26      1        46.63       2.561        NaN        NaN
# 4  2010-03-05      1        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
# Step 2: set index as datetime
df['Date'] = pd.to_datetime(df['Date']) # change to date time
df.index = df['Date']
df.head()
# Out:
#                  Date  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# Date
# 2010-02-05 2010-02-05      1        42.31       2.572        NaN        NaN
# 2010-02-12 2010-02-12      1        38.51       2.548        NaN        NaN
# 2010-02-19 2010-02-19      1        39.93       2.514        NaN        NaN
# 2010-02-26 2010-02-26      1        46.63       2.561        NaN        NaN
# 2010-03-05 2010-03-05      1        46.50       2.625        NaN        NaN
#
#             MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# Date
# 2010-02-05        NaN        NaN        NaN  211.096358         8.106
# 2010-02-12        NaN        NaN        NaN  211.242170         8.106
# 2010-02-19        NaN        NaN        NaN  211.289143         8.106
# 2010-02-26        NaN        NaN        NaN  211.319643         8.106
# 2010-03-05        NaN        NaN        NaN  211.350143         8.106
#
#             IsHoliday
# Date
# 2010-02-05      False
# 2010-02-12       True
# 2010-02-19      False
# 2010-02-26      False
# 2010-03-05      False

# %%
df.info()
df.descripbe() # Statistical summary of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 182 entries, 2010-02-05 to 2013-07-26
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          182 non-null    datetime64[ns]
#  1   Store         182 non-null    int64
#  2   Temperature   182 non-null    float64
#  3   Fuel_Price    182 non-null    float64
#  4   MarkDown1     90 non-null     float64
#  5   MarkDown2     73 non-null     float64
#  6   MarkDown3     89 non-null     float64
#  7   MarkDown4     90 non-null     float64
#  8   MarkDown5     90 non-null     float64
#  9   CPI           169 non-null    float64
#  10  Unemployment  169 non-null    float64
#  11  IsHoliday     182 non-null    bool
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(1)
# memory usage: 17.2 KB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/91/gbg7fcg52bn_nx2ht6x1vgz00000gn/T/ipykernel_25524/3995500294.py in ?()
#       1 df.info()
# ----> 2 df.descripbe() # Statistical summary of the DataFrame
#
# /opt/miniconda3/envs/VE_Seminar/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'descripbe'

# %%
# Task 1: Select all rows in Feburary 2010
feb_2010_data = df.loc['2010-02']  #because we converted to datetime earlier
feb_2010_data
# Out:
#                  Date  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# Date
# 2010-02-05 2010-02-05      1        42.31       2.572        NaN        NaN
# 2010-02-12 2010-02-12      1        38.51       2.548        NaN        NaN
# 2010-02-19 2010-02-19      1        39.93       2.514        NaN        NaN
# 2010-02-26 2010-02-26      1        46.63       2.561        NaN        NaN
# 2010-03-05 2010-03-05      1        46.50       2.625        NaN        NaN
# 2010-03-12 2010-03-12      1        57.79       2.667        NaN        NaN
# 2010-03-19 2010-03-19      1        54.58       2.720        NaN        NaN
# 2010-03-26 2010-03-26      1        51.45       2.732        NaN        NaN
#
#             MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# Date
# 2010-02-05        NaN        NaN        NaN  211.096358         8.106
# 2010-02-12        NaN        NaN        NaN  211.242170         8.106
# 2010-02-19        NaN        NaN        NaN  211.289143         8.106
# 2010-02-26        NaN        NaN        NaN  211.319643         8.106
# 2010-03-05        NaN        NaN        NaN  211.350143         8.106
# 2010-03-12        NaN        NaN        NaN  211.380643         8.106
# 2010-03-19        NaN        NaN        NaN  211.215635         8.106
# 2010-03-26        NaN        NaN        NaN  211.018042         8.106
#
#             IsHoliday
# Date
# 2010-02-05      False
# 2010-02-12       True
# 2010-02-19      False
# 2010-02-26      False
# 2010-03-05      False
# 2010-03-12      False
# 2010-03-19      False
# 2010-03-26      False

# %%
df.['Date']
(df.)

# %%
# Alternative method using boolean masking

# If your 'Date' column is not the index or you prefer a method that doesn't rely on indexing, you can also do this:
feb_2010_data = df[(df.index >= '2010-02-01') & (df.index <= '2010-02-28')] # filtering with boolean masks # filter is inside the blackets

# Task 2: Select all rows from February(different years)
# Filter the DataFrame to only include rows where the month is February
february_data = df[df.index.month == 2] #wenn monat gleich zwei ist auch weil wir vorher schon converted haben zu datetime

# Alternative method: Use query to select February
february_data = df.query('Date.dt.month == 2') #unnötig

# %%
# Task 3: find the max date row:

# Find the maximum date oldest
# max_date = df['Date'].max() 

# Select the row(s) with the maximum date
# max_date_row = df[df['Date'] == max_date]


# Find the maximum date in the index #when you have done Date zu index
max_date_index = df.index.max()

# Retrieve the row with the maximum date
row_with_max_date = df.loc[max_date_index]

# %% [markdown]
# Difference between slicing with numbers and slicing with labels.
# - The __df.loc__ method is used for _label-based_ indexing, which means you use the __actual labels__ of your index to retrieve data. It can select rows, columns, or specific values based on these labels.
# - The __df.iloc__ method is used for _integer-location_ based indexing, meaning you use __integers__ to select the rows and columns. This method is primarily useful when you know the position (i.e., integer index) of the elements you want to access.

# %%
df.iloc[2:3] # counts the number
# Out:
#                  Date  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# Date
# 2010-02-19 2010-02-19      1        39.93       2.514        NaN        NaN
#
#             MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# Date
# 2010-02-19        NaN        NaN        NaN  211.289143         8.106
#
#             IsHoliday
# Date
# 2010-02-19      False

# %%
# We use reset_index to get the default range index instead of a date
df.reset_index(drop=True).loc[2:3] # selects 2 rows ! (Because 2:3 is a slice of labels) #n inclusive
# Out:
#         Date  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 2 2010-02-19      1        39.93       2.514        NaN        NaN        NaN
# 3 2010-02-26      1        46.63       2.561        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 2        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN  211.319643         8.106      False

# %%
# Access a single row by index label
row = df.loc['2010-03-05']

# Access multiple rows by index label
rows = df.loc[['2010-03-05', '2013-07-19']]

# %%
# Access specific columns across all rows
subset = df.loc[:, ['Temperature', 'Fuel_Price']]

# Access specific columns for specific rows #erst die zeilen dann die spalten auswählen
subset = df.loc[['2010-03-05', '2013-07-19'], ['Temperature', 'Fuel_Price']]

subset
# Out:
#             Temperature  Fuel_Price
# Date
# 2010-03-05        46.50       2.625
# 2013-07-19        79.26       3.556

# %% [markdown]
# Boolean Condition: (df['Temperature'] > 30) & (df['Temperature'] < 40) generates a boolean mask where each True represents a row in the DataFrame that meets both conditions.
# Using __df.loc__ with Boolean Array: Although df.loc is primarily used for label-based indexing, when given a boolean array, it filters the rows accordingly. This approach is very clean and explicit, making the code easy to read and understand.

# %%
# Task 5: filter
# Filter by truth or flase
# Apply the filter
filtered_df = df[(df['Temperature'] > 30) & (df['Temperature'] < 40)]
filtered_df
# Out:
#                  Date  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# Date
# 2010-02-12 2010-02-12      1        38.51       2.548        NaN        NaN
# 2010-02-19 2010-02-19      1        39.93       2.514        NaN        NaN
# 2011-01-14 2011-01-14      1        35.40       2.983        NaN        NaN
# 2011-02-11 2011-02-11      1        36.39       3.022        NaN        NaN
#
#             MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# Date
# 2010-02-12        NaN        NaN        NaN  211.242170         8.106
# 2010-02-19        NaN        NaN        NaN  211.289143         8.106
# 2011-01-14        NaN        NaN        NaN  211.457411         7.742
# 2011-02-11        NaN        NaN        NaN  212.936705         7.742
#
#             IsHoliday
# Date
# 2010-02-12       True
# 2010-02-19      False
# 2011-01-14      False
# 2011-02-11       True

# %%
# Task 5: filter
# Apply the filter
filtered_df = df[(df['Temperature'] > 30) & (df['Temperature'] < 40)]

# Filter using df.loc with a boolean condition
filtered_df = df.loc[(df['Temperature'] > 30) & (df['Temperature'] < 40)]

"""## Boolean Indexing"""

df['Temperature'] > 90

df[ (df['Temperature'] > 90) ]

df[ (df['Temperature'] >= 85) & (df['Temperature'] < 90)] # logical AND & sign

df[ (df['Temperature'] < 40) | (df['Temperature'] > 90)] # logical OR vertical bar

# %%
"""## Example: .(isin)"""
data = pd.DataFrame({'model': ['a', 'b', 'c'],
                     'price' : [1,2,3]})
data
# Out:
#   model  price
# 0     a      1
# 1     b      2
# 2     c      3

# %%
data[ (data['model'] == 'a') | (data['model'] == 'c')]

data['model'].isin(['a','c'])

data[data['model'].isin(['a','c'])]

data[data['model'].isin(['a','c'])]['price']

# %%
# Remove a column
temperature = df.pop('Temperature') #removes and returns the column in a variable
df.info()

# Re-insert it before the first column
df.insert(0, 'Temperature', temperature)
df.info()

# %% [markdown]
# ### Sorting and Sampling

# %%
df = pd.read_csv(path + 'store1features.csv')
df.index = pd.to_datetime(df['Date'])
df = df[['Temperature', 'Fuel_Price', 'IsHoliday']]
df.head()

df.sort_values(by='Temperature', ascending=[False]).head() #defalult is ascending true

df.sort_values(by=['IsHoliday', 'Temperature'], ascending=[False,False]).head() #sequential sort erst Holidays dann Temperature

subdf = df.sample(n=5) # This is random, so the result will change every time you run it
subdf

subdf.sort_index()

# %% [markdown]
# Farenheit to Celsius

# %%
df = pd.read_csv('store1features.csv')
df.index = pd.to_datetime(df['Date'])
df['Temperature'] = (df['Temperature'] - 32)*5/9 #Farenheit zu Celsius #eine Spalte umrechnen
df
#df['Temperature'] * df['Days'] multiplies table with table by index
df['Temp_x_Days'] = df['Temperature'] * df['Days'] # need the same index
# Out:
#                   Date  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# Date
# 2010-02-05  2010-02-05      1     5.727778       2.572        NaN        NaN
# 2010-02-12  2010-02-12      1     3.616667       2.548        NaN        NaN
# 2010-02-19  2010-02-19      1     4.405556       2.514        NaN        NaN
# 2010-02-26  2010-02-26      1     8.127778       2.561        NaN        NaN
# 2010-03-05  2010-03-05      1     8.055556       2.625        NaN        NaN
# ...                ...    ...          ...         ...        ...        ...
# 2013-06-28  2013-06-28      1    28.855556       3.495    4205.98     796.70
# 2013-07-05  2013-07-05      1    26.583333       3.422    7649.99    3503.29
# 2013-07-12  2013-07-12      1    28.400000       3.400    6089.94    1362.42
# 2013-07-19  2013-07-19      1    26.255556       3.556    3117.04    1060.39
# 2013-07-26  2013-07-26      1    27.522222       3.620     332.17     673.19
#
#             MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# Date
# 2010-02-05        NaN        NaN        NaN  211.096358         8.106
# 2010-02-12        NaN        NaN        NaN  211.242170         8.106
# 2010-02-19        NaN        NaN        NaN  211.289143         8.106
# 2010-02-26        NaN        NaN        NaN  211.319643         8.106
# 2010-03-05        NaN        NaN        NaN  211.350143         8.106
# ...               ...        ...        ...         ...           ...
# 2013-06-28       6.84    3816.78    4812.74         NaN           NaN
# 2013-07-05    1766.77    9454.96    1079.89         NaN           NaN
# 2013-07-12     209.62    2367.42    2651.05         NaN           NaN
# 2013-07-19     199.05    1012.30    5381.72         NaN           NaN
# 2013-07-26       1.00      38.63    1245.20         NaN           NaN
#
#             IsHoliday
# Date
# 2010-02-05      False
# 2010-02-12       True
# 2010-02-19      False
# 2010-02-26      False
# 2010-03-05      False
# ...               ...
# 2013-06-28      False
# 2013-07-05      False
# 2013-07-12      False
# 2013-07-19      False
# 2013-07-26      False
#
# [182 rows x 12 columns]

# %%
~df['IsHoliday']

# Same as
import numpy as np
np.logical_not(df['IsHoliday'])
# Out:
# Date
# 2010-02-05     True
# 2010-02-12    False
# 2010-02-19     True
# 2010-02-26     True
# 2010-03-05     True
#               ...
# 2013-06-28     True
# 2013-07-05     True
# 2013-07-12     True
# 2013-07-19     True
# 2013-07-26     True
# Name: IsHoliday, Length: 182, dtype: bool

# %% [markdown]
# xxxmissing data handling

# %%
df
# Out:
#                   Date  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# Date
# 2010-02-05  2010-02-05      1     5.727778       2.572        NaN        NaN
# 2010-02-12  2010-02-12      1     3.616667       2.548        NaN        NaN
# 2010-02-19  2010-02-19      1     4.405556       2.514        NaN        NaN
# 2010-02-26  2010-02-26      1     8.127778       2.561        NaN        NaN
# 2010-03-05  2010-03-05      1     8.055556       2.625        NaN        NaN
# ...                ...    ...          ...         ...        ...        ...
# 2013-06-28  2013-06-28      1    28.855556       3.495    4205.98     796.70
# 2013-07-05  2013-07-05      1    26.583333       3.422    7649.99    3503.29
# 2013-07-12  2013-07-12      1    28.400000       3.400    6089.94    1362.42
# 2013-07-19  2013-07-19      1    26.255556       3.556    3117.04    1060.39
# 2013-07-26  2013-07-26      1    27.522222       3.620     332.17     673.19
#
#             MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# Date
# 2010-02-05        NaN        NaN        NaN  211.096358         8.106
# 2010-02-12        NaN        NaN        NaN  211.242170         8.106
# 2010-02-19        NaN        NaN        NaN  211.289143         8.106
# 2010-02-26        NaN        NaN        NaN  211.319643         8.106
# 2010-03-05        NaN        NaN        NaN  211.350143         8.106
# ...               ...        ...        ...         ...           ...
# 2013-06-28       6.84    3816.78    4812.74         NaN           NaN
# 2013-07-05    1766.77    9454.96    1079.89         NaN           NaN
# 2013-07-12     209.62    2367.42    2651.05         NaN           NaN
# 2013-07-19     199.05    1012.30    5381.72         NaN           NaN
# 2013-07-26       1.00      38.63    1245.20         NaN           NaN
#
#             IsHoliday
# Date
# 2010-02-05      False
# 2010-02-12       True
# 2010-02-19      False
# 2010-02-26      False
# 2010-03-05      False
# ...               ...
# 2013-06-28      False
# 2013-07-05      False
# 2013-07-12      False
# 2013-07-19      False
# 2013-07-26      False
#
# [182 rows x 12 columns]

# %%
# This works with non-floating-point columns

# if you want to use np.isnan(df), make sure df is all floating numbers

df['MarkDown1'].notna() #missing value
sum(df['MarkDown1'].notna()) #sum of missing values
#.info() für Übersicht aber wenn zu viele Zeilen dann gehts nicht


# or

~df['MarkDown1'].isna() #is not missing value
# Out:
# Date
# 2010-02-05    False
# 2010-02-12    False
# 2010-02-19    False
# 2010-02-26    False
# 2010-03-05    False
#               ...
# 2013-06-28     True
# 2013-07-05     True
# 2013-07-12     True
# 2013-07-19     True
# 2013-07-26     True
# Name: MarkDown1, Length: 182, dtype: bool

# %%
import numpy as np

df[df['MarkDown1'].notna() & df['MarkDown2'].notna() & df['MarkDown3'].notna() & ~df['MarkDown4'].isna()]

#~ means not
# or

df[df[['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4']].notna().all(axis=1)]
# Out:
#                   Date  Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# Date
# 2011-11-11  2011-11-11      1    15.061111       3.297   10382.90    6115.67
# 2011-11-18  2011-11-18      1    16.805556       3.308    6074.12     254.39
# 2011-11-25  2011-11-25      1    15.633333       3.236     410.31      98.00
# 2011-12-02  2011-12-02      1     9.394444       3.172    5629.51      68.00
# 2011-12-09  2011-12-09      1     6.627778       3.158    4640.65      19.00
# ...                ...    ...          ...         ...        ...        ...
# 2013-06-28  2013-06-28      1    28.855556       3.495    4205.98     796.70
# 2013-07-05  2013-07-05      1    26.583333       3.422    7649.99    3503.29
# 2013-07-12  2013-07-12      1    28.400000       3.400    6089.94    1362.42
# 2013-07-19  2013-07-19      1    26.255556       3.556    3117.04    1060.39
# 2013-07-26  2013-07-26      1    27.522222       3.620     332.17     673.19
#
#             MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# Date
# 2011-11-11     215.07    2406.62    6551.42  217.998085         7.866
# 2011-11-18      51.98     427.39    5988.57  218.220509         7.866
# 2011-11-25   55805.51       8.00     554.92  218.467621         7.866
# 2011-12-02    1398.11    2084.64   20475.32  218.714733         7.866
# 2011-12-09     105.02    3639.42   14461.82  218.961846         7.866
# ...               ...        ...        ...         ...           ...
# 2013-06-28       6.84    3816.78    4812.74         NaN           NaN
# 2013-07-05    1766.77    9454.96    1079.89         NaN           NaN
# 2013-07-12     209.62    2367.42    2651.05         NaN           NaN
# 2013-07-19     199.05    1012.30    5381.72         NaN           NaN
# 2013-07-26       1.00      38.63    1245.20         NaN           NaN
#
#             IsHoliday
# Date
# 2011-11-11      False
# 2011-11-18      False
# 2011-11-25       True
# 2011-12-02      False
# 2011-12-09      False
# ...               ...
# 2013-06-28      False
# 2013-07-05      False
# 2013-07-12      False
# 2013-07-19      False
# 2013-07-26      False
#
# [72 rows x 12 columns]

# %%
df.dropna(axis = 0) # Rows
df.dropna(axis = 1) # Columns

# %%
# fill na -> fill the leer 
# should assign it to a column
.fill(0)# all of the missing values will be filled with 0
df['MarkDown1'] = df['MarkDown1'].fillna(df['MarkDown1'].mean())#fill missing values with the mean o the column
df
# Out:
#                   Date  Store  Temperature  Fuel_Price    MarkDown1  \
# Date
# 2010-02-05  2010-02-05      1     5.727778       2.572  8536.592778
# 2010-02-12  2010-02-12      1     3.616667       2.548  8536.592778
# 2010-02-19  2010-02-19      1     4.405556       2.514  8536.592778
# 2010-02-26  2010-02-26      1     8.127778       2.561  8536.592778
# 2010-03-05  2010-03-05      1     8.055556       2.625  8536.592778
# ...                ...    ...          ...         ...          ...
# 2013-06-28  2013-06-28      1    28.855556       3.495  4205.980000
# 2013-07-05  2013-07-05      1    26.583333       3.422  7649.990000
# 2013-07-12  2013-07-12      1    28.400000       3.400  6089.940000
# 2013-07-19  2013-07-19      1    26.255556       3.556  3117.040000
# 2013-07-26  2013-07-26      1    27.522222       3.620   332.170000
#
#             MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# Date
# 2010-02-05        NaN        NaN        NaN        NaN  211.096358
# 2010-02-12        NaN        NaN        NaN        NaN  211.242170
# 2010-02-19        NaN        NaN        NaN        NaN  211.289143
# 2010-02-26        NaN        NaN        NaN        NaN  211.319643
# 2010-03-05        NaN        NaN        NaN        NaN  211.350143
# ...               ...        ...        ...        ...         ...
# 2013-06-28     796.70       6.84    3816.78    4812.74         NaN
# 2013-07-05    3503.29    1766.77    9454.96    1079.89         NaN
# 2013-07-12    1362.42     209.62    2367.42    2651.05         NaN
# 2013-07-19    1060.39     199.05    1012.30    5381.72         NaN
# 2013-07-26     673.19       1.00      38.63    1245.20         NaN
#
#             Unemployment  IsHoliday
# Date
# 2010-02-05         8.106      False
# 2010-02-12         8.106       True
# 2010-02-19         8.106      False
# 2010-02-26         8.106      False
# 2010-03-05         8.106      False
# ...                  ...        ...
# 2013-06-28           NaN      False
# 2013-07-05           NaN      False
# 2013-07-12           NaN      False
# 2013-07-19           NaN      False
# 2013-07-26           NaN      False
#
# [182 rows x 12 columns]

# %% [markdown]
# Automatic Index Alignment

# %%
sales = pd.DataFrame([['a', 1, 1, -1],
                     ['b', 1, 2, 2],
                     ['a', 2, 3, -1],
                     ['b', 2, 4, 2]], columns = ['model', 'shop', 'sales', 'price'])
sales
# Out:
#   model  shop  sales  price
# 0     a     1      1     -1
# 1     b     1      2      2
# 2     a     2      3     -1
# 3     b     2      4      2

# %%
dics = {'a':"apple", "b":"banana"} #first dictionary for the mapping

# %% [markdown]
# sales['model'].nunique () # Anzahl unique values in der Spalte Model, geht auch mit den row per xaxis = 1
# sales['model'].unique () #  unique values in der Spalte Model, geht auch mit per xaxis = 1

# %%
sales['model'] = sales['model'].map(dics) #map the values according to the dictionary
sales
# Out:
#     model  shop  sales  price
# 0   apple     1      1     -1
# 1  banana     1      2      2
# 2   apple     2      3     -1
# 3  banana     2      4      2

# %% [markdown]
# ### Web Scrapping Example

# %%
df = pd.read_csv('data_0_30.csv')
df
# Out:
#      Unnamed: 0                                            reviews  \
# 0             0  A quintessential and popular Biergarten in the...
# 1             1  Awesome medieval tavern vibe. Delicious sausag...
# 2             2  Visiting the Hofbräuhaus while in Munich is de...
# 3             3  Came here for a beer and had a great experienc...
# 4             4  A must visit when in Munich.  Part of a chain,...
# ..          ...                                                ...
# 297         297  Yeah, I know that this place is an institution...
# 298         298  Nice exerience and they have their own brand-s...
# 299         299  The whole roasted pork was very nice comparing...
# 300         300  Good beer, good food, terrible service. The se...
# 301         301  We really liked this place! It's an institutio...
#
#              date  rating
# 0    May 10, 2024     4.0
# 1     Apr 4, 2024     5.0
# 2     Apr 1, 2024     5.0
# 3    Apr 19, 2024     5.0
# 4    May 28, 2024     5.0
# ..            ...     ...
# 297  Jun 19, 2019     2.0
# 298  Jul 27, 2022     5.0
# 299  Dec 25, 2017     5.0
# 300  Jul 28, 2021     3.0
# 301   Nov 1, 2017     5.0
#
# [302 rows x 4 columns]

# %%
df['date'] = pd.to_datetime(df['date'],format="mixed")

# %% [markdown]
# df['year'] = df['date'].dt.year
# df['month'] = df['date'].dt.month
# df['day'] = df['date'].dt.day
# df

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['week'] = df['date'].dt.isocalendar().week
df = df.drop(columns = 'Unnamed: 0')

# %%
import matplotlib.pyplot as plt

df = df.sort_values('date')
df
# Out:
#                                                reviews       date  rating  \
# 292  Walk in the door and you're hit by the Oom-pah... 2015-03-02     5.0
# 267  We didn't have a reservation and we were seate... 2015-12-06     4.0
# 263  Five stars to HB for hanging around Munich sin... 2015-12-10     5.0
# 252  The international Hofbrauhaus (HB) in Munich i... 2016-01-28     5.0
# 245  I really enjoyed my experience here.While ther... 2016-05-06     5.0
# ..                                                 ...        ...     ...
# 28   Avoid Sundays... we had such a great time the ... 2024-05-26     3.0
# 4    A must visit when in Munich.  Part of a chain,... 2024-05-28     5.0
# 43   The ambiance was great but the quality of food... 2024-06-02     4.0
# 12   We got off our train in Munich, and my husband... 2024-06-10     5.0
# 5    Don't go for the food. Go for the experience a... 2024-06-11     3.0
#
#      year  month  day  week
# 292  2015      3    2    10
# 267  2015     12    6    49
# 263  2015     12   10    50
# 252  2016      1   28     4
# 245  2016      5    6    18
# ..    ...    ...  ...   ...
# 28   2024      5   26    21
# 4    2024      5   28    22
# 43   2024      6    2    22
# 12   2024      6   10    24
# 5    2024      6   11    24
#
# [302 rows x 7 columns]

# %% [markdown]
# definition for expanding: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.expanding.html

# %%
df['cumulative_avg'] = df['rating'].expanding().mean() # cumulative average

# %%
import matplotlib.pyplot as plt

# Plot the cumulative average
plt.figure(figsize=(10, 6))#save.  img -> dpi = 300, 300 dots in a inch (# (10*300))
plt.plot(df['date'], df['cumulative_avg'], linestyle='-')

# Customize the plot
plt.title('Cumulative Average Rating Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Cumulative Average Rating', fontsize=12)
#plt.grid(True) # Netz
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

#plt.show() #auskommentieren, weil sonst wird nur ein leeres dokuemnt gespeichert, sobald es geplottet ist, ist es wieder weg
plt.savefig('cumulative_avg_rating.png', dpi=300, transparent=True) #can also be saved to pdf when .pdf is used instead of .png

# %%
#pip install plothly.express
import plotly.express as px #interaktive dashboard

fig = px.line(df, x='date', y='cumulative_avg', title='Cumulative Average Rating Over Time')

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Cumulative Average Rating',
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True),
    template='plotly_white'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[54], line 2
#       1 #pip install plothly.express
# ----> 2 import plotly.express as px #interaktive dashboard
#       4 fig = px.line(df, x='date', y='cumulative_avg', title='Cumulative Average Rating Over Time')
#       6 fig.update_layout(
#       7     xaxis_title='Date',
#       8     yaxis_title='Cumulative Average Rating',
#    (...)     11     template='plotly_white'
#      12 )
#
# ModuleNotFoundError: No module named 'plotly'

# %%
Appling method ot Data Fraem

# %%
axis = 'index' #mean for each column
axis = 'columns' #mean for each row
df.mean(axis=axis)
df.
pow2
df.apply (pow2) # apply a function that you each element of the DataFrame
# Out:
#   Cell In[55], line 4
#     df.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Convert Table form long to wide
# Long vs. WIde data
# for Machine Learing you need Wide format
# More readable when you convert it into the long data
# convert from wide to Long
#
# pd.melt(df,
# id_vars = 'Type', #column we are not going to do any change
# value_vars = ['New', 'Old]', #variable
# value_name = 'profit') ' #value
# var_name = 'Model')
#
# long -> wide
# dp.pivot(df)
#
# --------------------------------------------------------------------------
#
# Group By (-> Folien)
# #groupby.pandas examples im Internet auf der Website
# arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
#           ['Captive', 'Wild', 'Captive', 'Wild']]
# index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
# df = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
#                   index=index)
# df
#                 Max Speed
# Animal Type
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0
# df.groupby(level=0).mean() #level 0 is the first colom
#         Max Speed
# Animal
# Falcon      370.0
# Parrot       25.0
# df.groupby(level="Type").mean()
#          Max Speed
# Type
# Captive      210.0
# Wild         185.0
#
# df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
#                               'Parrot', 'Parrot'],
#                    'Max Speed': [380., 370., 24., 26.]})
# df.groupby("Animal", group_keys=True)[['Max Speed']].apply(lambda x: x) #dummy vairable only in the function to group
#           Max Speed
# Animal
# Falcon 0      380.0
#        1      370.0
# Parrot 2       24.0
#        3       26.0
#
# --------------------------------------------------------------------
#
# Missing Values
